# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from Amsterdam to Barcelona on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from Amsterdam to Barcelona on March 31st', additional_kwargs={}, response_metadata={}, id='fa4f7881-ea97-4de8-99c2-c05a82ed1b3b'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1234, 'prompt_tokens': 1228, 'total_tokens': 2462, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7hnpZDZq8Ej3Gya7M8PKCzh1d0RI', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c47ac-d616-7f71-9ab6-b9a2dbd74379-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'Amsterdam', 'flyTo': 'Barcelona', 'departureDate': '31/03/2026', 'departureDateFlexRange': 0, 'passengers': {'adults': 1, 'children': 0, 'infants': 0}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'EUR', 'locale': 'en'}, 'id': 'call_EcmthO8rVEyRpb7O7TPb7FCF', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1228, 'output_tokens': 1234, 'total_tokens': 2462, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "AMS",\n    "flyTo": "BCN",\n    "cityFrom": "Amsterdam",\n    "cityTo": "Barcelona",\n    "departure": {\n      "utc": "2026-03-31T03:45:00.000Z",\n      "local": "2026-03-31T05:45:00.000"\n    },\n    "arrival": {\n      "utc": "2026-03-31T05:55:00.000Z",\n      "local": "2026-03-31T07:55:00.000"\n    },\n    "totalDurationInSeconds": 7800,\n    "durationInSeconds": 7800,\n    "price": 69,\n    "deepLink": "https://on.kiwi.com/MQuuSc",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "AMS",\n    "flyTo": "BCN",\n    "cityFrom": "Amsterdam",\n    "cityTo": "Barcelona",\n    "departure": {\n      "utc": "2026-03-31T16:55:00.000Z",\n      "local": "2026-03-31T18:55:00.000"\n    },\n    "arrival": {\n      "utc": "2026-03-31T19:05:00.000Z",\n      "local": "2026-03-31T21:05:00.000"\n    },\n    "totalDurationInSeconds": 7800,\n    "durationInSeconds": 7800,\n    "price": 84,\n    "deepLink": "https://on.kiwi.com/EysCwX",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "AMS",\n    "flyTo": "BCN",\n    "cityFrom": "Amsterdam",\n    "cityTo": "Barcelona",\n    "departure": {\n      "utc": "2026-03-31T12:25:00.000Z",\n      "local": "2026-03-31T14:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-03-31T14:45:00.000Z",\n      "local": "2026-03-31T16:45:00.000"\n    },\n    "totalDurationInSeconds": 8400,\n    "durationInSeconds": 8400,\n    "price": 87,\n    "deepLink": "https://on.kiwi.com/FSrRCE",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "AMS",\n    "flyTo": "BCN",\n    "cityFrom": "Amsterdam",\n    "cityTo": "Barcelona",\n    "departure": {\n      "utc": "2026-03-31T05:00:00.000Z",\n      "local": "2026-03-31T07:00:00.000"\n    },\n    "arrival": {\n      "utc": "2026-03-31T07:25:00.000Z",\n      "local": "2026-03-31T09:25:00.000"\n    },\n    "totalDurationInSeconds": 8700,\n    "durationInSeconds": 8700,\n    "price": 93,\n    "deepLink": "https://on.kiwi.com/LITfO8",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "AMS",\n    "flyTo": "BCN",\n    "cityFrom": "Amsterdam",\n    "cityTo": "Barcelona",\n    "departure": {\n      "utc": "2026-03-31T19:25:00.000Z",\n      "local": "2026-03-31T21:25:00.000"\n    },\n    "arrival": {\n      "utc": "2026-03-31T21:45:00.000Z",\n      "local": "2026-03-31T23:45:00.000"\n    },\n    "totalDurationInSeconds": 8400,\n    "durationInSeconds": 8400,\n    "price": 96,\n    "deepLink": "https://on.kiwi.com/mLC2xi",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "AMS",\n    "flyTo": "BCN",\n    "cityFrom": "Amsterdam",\n    "cityTo": "Barcelona",\n    "departure": {\n      "utc": "2026-03-31T16:35:00.000Z",\n      "local": "2026-03-31T18:35:00.000"\n    },\n    "arrival": {\n      "utc": "2026-03-31T18:55:00.000Z",\n      "local": "2026-03-31T20:55:00.000"\n    },\n    "totalDurationInSeconds": 8400,\n    "durationInSeconds": 8400,\n    "price": 103,\n    "deepLink": "https://on.kiwi.com/PQen72",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "AMS",\n    "flyTo": "BCN",\n    "cityFrom": "Amsterdam",\n    "cityTo": "Barcelona",\n    "departure": {\n      "utc": "2026-03-31T18:35:00.000Z",\n      "local": "2026-03-31T20:35:00.000"\n    },\n    "arrival": {\n      "utc": "2026-03-31T20:45:00.000Z",\n      "local": "2026-03-31T22:45:00.000"\n    },\n    "totalDurationInSeconds": 7800,\n    "durationInSeconds": 7800,\n    "price": 121,\n    "deepLink": "https://on.kiwi.com/08MTqO",\n    "currency": "EUR"\n  },\n  {\n    "flyFrom": "AMS",\n    "flyTo": "BCN",\n    "cityFrom": "Amsterdam",\n    "cityTo": "Barcelona",\n    "departure": {\n      "utc": "2026-03-31T04:35:00.000Z",\n      "local": "2026-03-31T06:35:00.000"\n    },\n    "arrival": {\n      "utc": "2026-03-31T06:45:00.000Z",\n      "local": "2026-03-31T08:45:00.000"\n    },\n    "totalDurationInSeconds": 7800,\n    "durationInSeconds": 7800,\n    "price": 121,\n    "deepLink": "https://on.kiwi.com/9HcGVh",\n    "currency": "EUR"\n  } ...
#               AIMessage(content='Here are direct AMS → BCN flights for March 31st. All are one-way Economy (no return leg shown).\n\nCheapest flights\n| Route | Schedule | Cabin | Return Route | Return Schedule | Return Cabin | Price | Deep link |\n|---|---|---|---|---|---|---|---|\n| AMS → BCN | 31/03/2026 05:45 → 07:55 (2h 10m) | Economy | — | — | — | 69 EUR | https://on.kiwi.com/MQuuSc |\n\nShortest flights\n| Route | Schedule | Cabin | Return Route | Return Schedule | Return Cabin | Price | Deep link |\n|---|---|---|---|---|---|---|---|\n| AMS → BCN | 31/03/2026 16:45 → 18:50 (2h 05m) | Economy | — | — | — | 155 EUR | https://on.kiwi.com/2H5Crn |\n\nOther interesting direct options (sorted by price)\n| Route | Schedule | Cabin | Return Route | Return Schedule | Return Cabin | Price | Deep link |\n|---|---|---|---|---|---|---|---|\n| AMS → BCN | 31/03/
 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 4608}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct AMS → BCN flights for March 31st. All are one-way Economy (no return leg shown).
#
# Cheapest flights
# | Route | Schedule | Cabin | Return Route | Return Schedule | Return Cabin | Price | Deep link |
# |---|---|---|---|---|---|---|---|
# | AMS → BCN | 31/03/2026 05:45 → 07:55 (2h 10m) | Economy | — | — | — | 69 EUR | https://on.kiwi.com/MQuuSc |
#
# Shortest flights
# | Route | Schedule | Cabin | Return Route | Return Schedule | Return Cabin | Price | Deep link |
# |---|---|---|---|---|---|---|---|
# | AMS → BCN | 31/03/2026 16:45 → 18:50 (2h 05m) | Economy | — | — | — | 155 EUR | https://on.kiwi.com/2H5Crn |
#
# Other interesting direct options (sorted by price)
# | Route | Schedule | Cabin | Return Route | Return Schedule | Return Cabin | Price | Deep link |
# |---|---|---|---|---|---|---|---|
# | AMS → BCN | 31/03/2026 16:55 → 21:05 (2h 10m) | Economy | — | — | — | 84 EUR | https://on.kiwi.com/EysCwX |
# | AMS → BCN | 31/03/2026 12:25 → 16:45 (2h 20m) | Economy | — | — | — | 87 EUR | https://on.kiwi.com/FSrRCE |
# | AMS → BCN | 31/03/2026 05:00 → 09:25 (4h 25m) | Economy | — | — | — | 93 EUR | https://on.kiwi.com/LITfO8 |
# | AMS → BCN | 31/03/2026 19:25 → 23:45 (4h 20m) | Economy | — | — | — | 96 EUR | https://on.kiwi.com/mLC2xi |
# | AMS → BCN | 31/03/2026 16:35 → 20:55 (4h 20m) | Economy | — | — | — | 103 EUR | https://on.kiwi.com/PQen72 |
# | AMS → BCN | 31/03/2026 18:35 → 22:45 (4h 10m) | Economy | — | — | — | 121 EUR | https://on.kiwi.com/08MTqO |
# | AMS → BCN | 31/03/2026 04:35 → 08:45 (4h 10m) | Economy | — | — | — | 121 EUR | https://on.kiwi.com/9HcGVh |
# | AMS → BCN | 31/03/2026 06:05 → 10:15 (4h 10m) | Economy | — | — | — | 121 EUR | https://on.kiwi.com/AeIaQo |
# | AMS → BCN | 31/03/2026 11:25 → 15:45 (4h 20m) | Economy | — | — | — | 124 EUR | https://on.kiwi.com/7Zw2yd |
# | AMS → BCN | 31/03/2026 12:25 → 16:45 (4h 20m) | Economy | — | — | — | 128 EUR | https://on.kiwi.com/L7xMkC |
# | AMS → BCN | 31/03/2026 12:15 → 16:25 (4h 10m) | Economy | — | — | — | 132 EUR | https://on.kiwi.com/h3M6Ub |
# | AMS → BCN | 31/03/2026 19:25 → 23:45 (4h 20m) | Economy | — | — | — | 143 EUR | https://on.kiwi.com/sjWEXG |
# | AMS → BCN | 31/03/2026 05:00 → 09:25 (4h 25m) | Economy | — | — | — | 144 EUR | https://on.kiwi.com/1AmrZZ |
#
# Summary and recommendation
# - Best price: 69 EUR for the morning direct flight (Flight 1).
# - Shortest: 2h05m option in the late afternoon (Flight 15).
# - Recommendation: If price is king, pick the 69 EUR morning flight. If you prefer a very quick daytime option, the 2h05m late-afternoon flight is a strong choice.
#
# Have a wonderful trip to Barcelona! Fun fact: Barcelona is famed for Gaudí’s architecture, including the Sagrada Família, a landmark that has been under construction since 1882 and draws visitors from around the world.
