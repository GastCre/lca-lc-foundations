# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

# %%
from langchain.tools import tool

@tool
def sql_query(query: str) -> str:

    """Obtain information from the database using SQL queries"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

sql_query.invoke("SELECT * FROM Artist LIMIT 10")
# Out:
# /Users/sean/Documents/lca/demo/lc-foundations/.venv/lib/python3.12/site-packages/pydantic/v1/main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)
# "[(1, 'AC/DC'), (2, 'Accept'), (3, 'Aerosmith'), (4, 'Alanis Morissette'), (5, 'Alice In Chains'), (6, 'Antônio Carlos Jobim'), (7, 'Apocalyptica'), (8, 'Audioslave'), (9, 'BackBeat'), (10, 'Billy Cobham')]"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[sql_query]
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?", additional_kwargs={}, response_metadata={}, id='7f19fc7c-e939-4df7-aa66-0604930bd0be'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1320, 'prompt_tokens': 142, 'total_tokens': 1462, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1280, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CfZnMzhYnFzfHmWBOy2xWfb0KXKGi', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6cb3af4f-2a60-41cc-ae61-b7583a1797f0-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;"}, 'id': 'call_3NANQLD4FWK3AiGSEQCNPDB1', 'type': 'tool_call'}], usage_metadata={'input_tokens': 142, 'output_tokens': 1320, 'total_tokens': 1462, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1280}}),
#  ToolMessage(content="Error: (sqlite3.OperationalError) no such table: artists\n[SQL: SELECT name FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)", name='sql_query', id='423b201d-ab18-4e6e-9e05-f75fecd142cf', tool_call_id='call_3NANQLD4FWK3AiGSEQCNPDB1'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 228, 'prompt_tokens': 245, 'total_tokens': 473, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CfZnYWVQzXa8Z33xwUPY3v4C3E70D', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bdfc85f5-0e91-4ea4-ae8e-0402212b4d5d-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;"}, 'id': 'call_selt2qTSkhd98cDS9Df4CHUl', 'type': 'tool_call'}], usage_metadata={'input_tokens': 245, 'output_tokens': 228, 'total_tokens': 473, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#  ToolMessage(content="[('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]", name='sql_query', id='e8eefc4e-eab2-4bca-a002-48fe98e90426', tool_call_id='call_selt2qTSkhd98cDS9Df4CHUl'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1342, 'prompt_tokens': 334, 'total_tokens': 1676, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1216, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CfZnbT7zi1tCekrN2WlDl0ydnEVKY', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--80f76cfa-33f3-4756-b60f-aac6f1ed6222-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT s.Name FROM (SELECT a.ArtistId, a.Name, SUM(il.Quantity * il.UnitPrice) AS total_sales\nFROM Artist a\nJOIN Album al ON al.ArtistId = a.ArtistId\nJOIN Track t ON t.AlbumId = al.AlbumId\nJOIN InvoiceLine il ON il.TrackId = t.TrackId\nGROUP BY a.ArtistId, a.Name) AS s\nWHERE s.Name LIKE 'S%'\nORDER BY s.total_sales DESC\nLIMIT 1;"}, 'id': 'call_LhWqgVdnsopPZt5axthfCxbP', 'type': 'tool_call'}], usage_metadata={'input_tokens': 334, 'output_tokens': 1342, 'total_tokens': 1676, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1216}}),
#  ToolMessage(content="[('Smashing Pumpkins',)]", name='sql_query', id='230b728c-7a72-43f4-95bf-53b5fde685fe', tool_call_id='call_LhWqgVdnsopPZt5axthfCxbP'),
#  AIMessage(content='The most popular artist starting with "S" is Smashing Pumpkins.\n\nIf you’d like the exact total sales figure for this artist, I can fetch it as well.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 748, 'prompt_tokens': 473, 'total_tokens': 1221, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CfZnm4pvbQiXntgBSCHBzKlXEWtrD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--418f3f27-3adb-4e5b-92ab-55c79cd7fd3c-0', usage_metadata={'input_tokens': 473, 'output_tokens': 748, 'total_tokens': 1221, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})]

# %%
print(response["messages"][-3].tool_calls[0]['args']['query'])
# Out:
# SELECT s.Name FROM (SELECT a.ArtistId, a.Name, SUM(il.Quantity * il.UnitPrice) AS total_sales
# FROM Artist a
# JOIN Album al ON al.ArtistId = a.ArtistId
# JOIN Track t ON t.AlbumId = al.AlbumId
# JOIN InvoiceLine il ON il.TrackId = t.TrackId
# GROUP BY a.ArtistId, a.Name) AS s
# WHERE s.Name LIKE 'S%'
# ORDER BY s.total_sales DESC
# LIMIT 1;
