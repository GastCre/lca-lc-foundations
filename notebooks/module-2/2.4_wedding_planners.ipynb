# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Setup Tools

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.
    You may need to make multiple queries to iteratively find the best options.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre"""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. Delegate tasks to your specialists for flights, venues and playlists.
    First find all the information you need to update the state. Once that is done you can delegate the tasks.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, in the style of jazz")],
    }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, in the style of jazz", additional_kwargs={}, response_metadata={}, id='d94cc7ef-5822-4f52-928f-da88c9b11252'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 421, 'prompt_tokens': 295, 'total_tokens': 716, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CjChWnAnuWiq35TFBa0aYvFNbxw2a', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--ec1c3880-ff95-4af5-b56f-7f59497dd94d-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'jazz'}, 'id': 'call_xGtUsOZTHK0V8oSErykKXyxs', 'type': 'tool_call'}], usage_metadata={'input_tokens': 295, 'output_tokens': 421, 'total_tokens': 716, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='e63910b1-cdeb-42ec-9498-d05841343db0', tool_call_id='call_xGtUsOZTHK0V8oSErykKXyxs'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 382, 'prompt_tokens': 340, 'total_tokens': 722, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CjCha0aYb1VGDxcqThhLbRAksx2JK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--ef370d00-12bf-4884-8d8e-85247f121998-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_8ta6C8b7dSF3iUxxd3qgtybf', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {}, 'id': 'call_lunJ179iU9JCdPfdEeZUwGNy', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {}, 'id': 'call_USJui3lwaRjAg7afzkjkfx9A', 'type': 'tool_call'}], usage_metadata={'input_tokens': 340, 'output_tokens': 382, 'total_tokens': 722, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#               ToolMessage(content='Here are the best one-way London to Paris flight options found, focusing on price, shortest duration, and a wedding-friendly travel window. For a Paris wedding, late spring to early summer (May–June) often gives pleasant weather and good venue availability.\n\nShortlist\n\n1) Cheapest options (price: 53 EUR)\n- Route: London Luton (LTN) → Paris CDG\n  - Times: 01/06/2026 05:05 (local) → 06:30 (local) [about 1h25m]\n  - Cabin: Economy\n  - Price: 53 EUR\n  - Deep link: https://on.kiwi.com/rldFqk\n\n- Route: London Luton (LTN) → Paris CDG\n  - Times: 01/06/2026 18:40 (local) → 20:00 (local) [about 1h20m]\n  - Cabin: Economy\n  - Price: 53 EUR\n  - Deep link: https://on.kiwi.com/l8TAgs\n\n2) Shortest duration option (duration: 1h10m)\n- Route: London Stansted (STN) → Paris CDG\n  - Times: 01/06/2026 14:35 (local) → 15:45 (local) [about 1h10m]\n  - Cabin: Economy\n  - Price: 58 EUR\n  - Deep link: https://on.kiwi.com/6OipA8\n\n3) Other notable cheap options (useful to compare)\n- Route: London Gatwick (LGW) → Paris Orly (ORY)\n  - Times: 01/06/2026 14:05 (local) → 15:30 (local) [about 1h25m]\n  - Cabin: Economy\n  - Price: 56 EUR\n  - Deep link: https://on.kiwi.com/PGBqwe\n\n- Route: London Luton (LTN) → Paris CDG\n  - Times: 01/06/2026 12:55 (local) → 14:20 (local) [about 1h25m]\n  - Cabin: Economy\n  - Price: 57 EUR\n  - Deep link: https://on.kiwi.com/O6ZSSj\n\n- Route: London Gatwick (LGW) → Paris CDG\n  - Times: 01/06/2026 12:35? → 15:25 (local) [about 2h50m total; 2h20m shown by data here]\n  - Cabin: Economy\n  - Price: 63 EUR\n  - Deep link: https://on.kiwi.com/a7iqvG\n\nNotes\n- All options shown are one-way economy-class fares sourced via Kiwi (prices in EUR).\n- Times shown are local to the departure/arrival airports.\n- If you’re aiming for a wedding trip in Paris, late May to early June typically offers comfortable weather (often around 18–23°C) and good venue availability.\n- If you’d like, I can expand or tailor the search to include specific dates around your ideal wedding window (e.g., May 25–June 5) or specific airports (LHR/LGW/STN/LTN) to fine-tune options.\n\nHave a wonderful trip! Fun fact: Paris is famed for its bakeries—there are thousands of them, and you’ll find a fresh baguette or croissant on almost every corner.', name='search_flights', id='f3381903-4a05-45f2-8979-d294885a69c6', tool_call_id='call_8ta6C8b7dSF3iUxxd3qgtybf'),
#               ToolMessage(content='Here are the best Paris wedding venues that can accommodate 100 guests, prioritized by having an exact or clear 100-person capacity and strong reviews.\n\n1) Castille Paris – Castille Paris, 1st arrondissement\n- Capacity: 100 (largest event space listed as 100)\n- Why it fits: Central, elegant 5-star boutique hotel with multiple intimate spaces for ceremonies/receptions; strong reputation for personalized service.\n- Notes on price: Not publicly posted; premium pricing typical for Castille. Request a quote for exact figures.\n- Reviews: Consistently strong for a boutique luxury venue; widely recommended in Paris wedding guides.\n- Source: collezione.starhotels.com/en/our-hotels/castille-paris/meetings-events/weddings-e-celebrations-at-castille.html (lists 100 capacity)\n\n2) The Peninsula Paris – The Peninsula Paris\n- Capacity: Up to 100 guests for a large, soundproofed ballroom (100 is the cap; suitable for 100)\n- Why it fits: Iconic modern luxury hotel with impeccable service, culinary excellence, and established wedding packages.\n- Notes on price: Not publicly posted; premium pricing typical for Peninsula; request a quote for exact figures.\n- Reviews: Extremely high (luxury brand with strong guest reviews)\n- Source: peninsula.com/en/paris/events/hotel-wedding-venues (notes up to 100 guests in the ballroom)\n\n3) Four Seasons Hotel George V – Paris\n- Capacity: Up to 100 guests for receptions\n- Why it fits: Legendary luxury hotel with renowned service, catering, and decor; superb venue for a classic Paris wedding.\n- Notes on price: Not publicly posted; expect premium wedding pricing; request a quote.\n- Reviews: Very strong (consistently top-rated among Paris hotels)\n- Source: fourseasons.com/paris/weddings/venues (mentions up to 100 guests for receptions)\n\nOptional alternative with 100-capability for cocktail-style format:\n- Hotel Le Marois (Paris) – capacity around 100 for certain configurations (some sources list cocktails up to 100). If you’re planning a cocktail-driven reception, this can be a fit, but verify exact 100-capacity for your layout.\n- Source examples show cocktail capacity around 100 for Le Marois; confirm with venue for your wedding format.\n\nNotes\n- All three primary options are in central Paris and are premium choices with strong reputations for weddings.\n- Public price data for wedding packages are not typically published; you’ll need to request quotes from each property for exact numbers.\n- If you want, I can summarize typical price ranges from industry sources, or help you compare included services (catering, staffing, decor, A/V) across these venues.\n\nWould you like a quick comparison of what each venue typically includes in their wedding packages (catering style, included furniture, staffing, and what’s usually extra) to help you decide?', name='search_venues', id='389a3b4b-b3af-4eb6-968c-4738303150c5', tool_call_id='call_lunJ179iU9JCdPfdEeZUwGNy'),
#               ToolMessage(content="I found a solid set of jazz tracks that work well for a wedding vibe—smooth classics with a few upbeat swing tracks to keep the floor open. Here’s a curated 20-song playlist, in a nice flow from laid-back to dance-friendly.\n\n1) Outra Vez — Antonio Carlos Jobim — Warner 25 Anos — 2:07 — $0.99\n2) Fotografia — Antonio Carlos Jobim — Warner 25 Anos — 2:09 — $0.99\n3) Desafinado — Antonio Carlos Jobim — Warner 25 Anos — 3:05 — $0.99\n4) Corcovado (Quiet Nights Of Quiet Stars) — Antonio Carlos Jobim — Warner 25 Anos — 3:26 — $0.99\n5) Samba De Uma Nota Só (One Note Samba) — Antonio Carlos Jobim — Warner 25 Anos — 2:17 — $0.99\n6) Se Todos Fossem Iguais A Você (Instrumental) — Antonio Carlos Jobim — Warner 25 Anos — 2:15 — $0.99\n7) Angela — Antonio Carlos Jobim — Warner 25 Anos — 2:49 — $0.99\n8) Por Causa De Você — Antonio Carlos Jobim — Warner 25 Anos — 2:50 — $0.99\n9) Lament — Miles Davis — Miles Ahead — 2:14 — $0.99\n10) The Meaning Of The Blues — Miles Davis — Miles Ahead — 2:48 — $0.99\n11) Summertime — Miles Davis — The Essential Miles Davis [Disc 1] — 3:20 — $0.99\n12) Now's The Time — Miles Davis — The Essential Miles Davis [Disc 1] — 3:17 — $0.99\n13) Drum Boogie — Gene Krupa — Up An' Atom — 3:12 — $0.99\n14) Up An' Atom — Gene Krupa — Up An' Atom — 2:59 — $0.99\n15) Opus No.1 — Gene Krupa — Up An' Atom — 2:59 — $0.99\n16) Leave Us Leap — Gene Krupa — Up An' Atom — 3:03 — $0.99\n17) Jeepers Creepers — Gene Krupa — Up An' Atom — 3:06 — $0.99\n18) How High The Moon — Gene Krupa — Up An' Atom — 3:21 — $0.99\n19) The Duke — Miles Davis — Miles Ahead — 3:35 — $0.99\n20) Falando De Amor — Antonio Carlos Jobim — Warner 25 Anos — 3:40 — $0.99\n\nTotals\n- Total duration: approximately 58 minutes and 32 seconds\n- Total cost: $19.80\n\nNotes and options\n- This set blends bossa nova (Jobim) with classic jazz standards (Miles Davis) and swing (Gene Krupa) for a timeless, wedding-appropriate vibe.\n- If you’d like a shorter version (e.g., 12–15 tracks) for a cocktail or dinner segment, I can trim it down while preserving the mood.\n- If you prefer more vocals or more upbeat dance tracks, I can swap in additional vocal standards or lighter swing tunes.\n\nWould you like me to reorder this into a timeline (e.g., cocktail hour, dinner, dancing) or tailor it to a specific tempo or vibe (more relaxed, more energetic, more vocal)?", name='suggest_playlist', id='8a307c1d-9941-4cfa-a404-11dc23396d4c', tool_call_id='call_USJui3lwaRjAg7afzkjkfx9A'),
#               AIMessage(content='Fantastic! Here’s the current state and a plan to move forward. I’ve organized tasks for your specialists (flights, venues, and playlists) and outlined recommended options based on your brief: London to Paris, 100 guests, jazz style.\n\nWhat we have so far\n- Origin: London\n- Destination: Paris\n- Guest count: 100\n- Style/genre: Jazz\n\nFlight options (for guests arriving in Paris)\n- Cheapest one-way options (around 53 EUR):\n  - Luton (LTN) → Paris CDG: 01 Jun 2026, 05:05–06:30\n  - Luton (LTN) → Paris CDG: 01 Jun 2026, 18:40–20:00\n- Shortest duration option:\n  - Stansted (STN) → Paris CDG: 01 Jun 2026, 14:35–15:45 (about 1h10m)\n- Other useful options:\n  - Gatwick (LGW) → Paris Orly (ORY): 14:05–15:30\n  - Luton (LTN) → Paris CDG: 12:55–14:20\n  - Gatwick (LGW) → Paris CDG: 12:35–15:25 (longer total time)\nNotes for flights:\n- Focus window: late May to early June is a great wedding window in Paris (pleasant weather, good venue availability).\n- If you’d like, we can tailor by specific dates around your ideal window and preferred departure airports (LHR, LGW, LTN, STN).\n\nParis venues (100-person capacity, strong options)\nTop three, central Paris, with 100-capacity notes:\n1) Castille Paris (1st arrondissement)\n   - Capacity: Listed as 100\n   - Why it fits: Elegant boutique hotel, central location, good ceremony/reception flow, strong service reputation\n   - Price: Not publicly posted; quotes needed\n   - Notes: Excellent for a refined, intimate Paris wedding feel\n2) The Peninsula Paris\n   - Capacity: Up to 100 guests in a large ballroom\n   - Why it fits: Iconic luxury, superb service and catering, polished packages\n   - Price: Premium; quotes needed\n   - Notes: Luxe, classic Paris experience\n3) Four Seasons Hotel George V – Paris\n   - Capacity: Up to 100 guests for receptions\n   - Why it fits: Legendary luxury, top-tier catering and decor\n   - Price: Premium; quotes needed\n   - Notes: Classic, timeless Paris wedding ambiance\nOptional alternative (if you’re planning a cocktail-style reception): Hotel Le Marois (some layouts list cocktail capacity around 100)\nWhat I’ll arrange for you:\n- Obtain formal quotes and availability from Castille Paris, The Peninsula Paris, and Four Seasons George V for your preferred date range.\n- Prepare a comparison matrix (catering inclusions, décor, A/V, staffing, rental fees, service charges, and potential corkage if applicable).\n- Confirm feasibility for your Jazz theme (sound restrictions, preferred ceremony/reception layout, space for live music vs. DJ).\n\nJazz playlist and music plan\n- Current playlist (20 tracks) blends bossa nova/jazz standards (Jobim, Miles Davis, Gene Krupa) with a smooth-to-upbeat flow.\n- Suggested use: cocktail hour background (laid-back to mid-tempo), dinner ambiance, and then dance sets.\nNext steps for the music specialist:\n- Create a timeline-based playlist: cocktail hour (~30–40 min), dinner (~60–90 min), dancing (~2 sets of 40–60 min), with a few high-energy swing tracks to get people on the floor.\n- Provide two options: (A) DJ-curated Jazz/Classic Mix with live-sounding transitions; (B) Small jazz ensemble (e.g., a quartet) with curated backing tracks for the dinner/dance segments.\n- Add a short “Must play / Do not play” list (e.g., preference for vocal jazz vs. instrumental, any songs to avoid).\n- Ensure licensing/royalty considerations are covered for public performance.\n\nRecommended initial direction (my pick)\n- Venue: The Peninsula Paris or Castille Paris are the strongest “first pass” options for a 100-guest jazz wedding in central Paris. The Peninsula offers a grand ballroom feel; Castille offers boutique charm with excellent service and potential for a more intimate ambiance. I’d start with these two to compare experience and quotes, and keep Four Seasons George V as a premium backup.\n- Flight strategy: Propose a small set of flight options that cover both budget-friendly and timing fl ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Fantastic! Here’s the current state and a plan to move forward. I’ve organized tasks for your specialists (flights, venues, and playlists) and outlined recommended options based on your brief: London to Paris, 100 guests, jazz style.
#
# What we have so far
# - Origin: London
# - Destination: Paris
# - Guest count: 100
# - Style/genre: Jazz
#
# Flight options (for guests arriving in Paris)
# - Cheapest one-way options (around 53 EUR):
#   - Luton (LTN) → Paris CDG: 01 Jun 2026, 05:05–06:30
#   - Luton (LTN) → Paris CDG: 01 Jun 2026, 18:40–20:00
# - Shortest duration option:
#   - Stansted (STN) → Paris CDG: 01 Jun 2026, 14:35–15:45 (about 1h10m)
# - Other useful options:
#   - Gatwick (LGW) → Paris Orly (ORY): 14:05–15:30
#   - Luton (LTN) → Paris CDG: 12:55–14:20
#   - Gatwick (LGW) → Paris CDG: 12:35–15:25 (longer total time)
# Notes for flights:
# - Focus window: late May to early June is a great wedding window in Paris (pleasant weather, good venue availability).
# - If you’d like, we can tailor by specific dates around your ideal window and preferred departure airports (LHR, LGW, LTN, STN).
#
# Paris venues (100-person capacity, strong options)
# Top three, central Paris, with 100-capacity notes:
# 1) Castille Paris (1st arrondissement)
#    - Capacity: Listed as 100
#    - Why it fits: Elegant boutique hotel, central location, good ceremony/reception flow, strong service reputation
#    - Price: Not publicly posted; quotes needed
#    - Notes: Excellent for a refined, intimate Paris wedding feel
# 2) The Peninsula Paris
#    - Capacity: Up to 100 guests in a large ballroom
#    - Why it fits: Iconic luxury, superb service and catering, polished packages
#    - Price: Premium; quotes needed
#    - Notes: Luxe, classic Paris experience
# 3) Four Seasons Hotel George V – Paris
#    - Capacity: Up to 100 guests for receptions
#    - Why it fits: Legendary luxury, top-tier catering and decor
#    - Price: Premium; quotes needed
#    - Notes: Classic, timeless Paris wedding ambiance
# Optional alternative (if you’re planning a cocktail-style reception): Hotel Le Marois (some layouts list cocktail capacity around 100)
# What I’ll arrange for you:
# - Obtain formal quotes and availability from Castille Paris, The Peninsula Paris, and Four Seasons George V for your preferred date range.
# - Prepare a comparison matrix (catering inclusions, décor, A/V, staffing, rental fees, service charges, and potential corkage if applicable).
# - Confirm feasibility for your Jazz theme (sound restrictions, preferred ceremony/reception layout, space for live music vs. DJ).
#
# Jazz playlist and music plan
# - Current playlist (20 tracks) blends bossa nova/jazz standards (Jobim, Miles Davis, Gene Krupa) with a smooth-to-upbeat flow.
# - Suggested use: cocktail hour background (laid-back to mid-tempo), dinner ambiance, and then dance sets.
# Next steps for the music specialist:
# - Create a timeline-based playlist: cocktail hour (~30–40 min), dinner (~60–90 min), dancing (~2 sets of 40–60 min), with a few high-energy swing tracks to get people on the floor.
# - Provide two options: (A) DJ-curated Jazz/Classic Mix with live-sounding transitions; (B) Small jazz ensemble (e.g., a quartet) with curated backing tracks for the dinner/dance segments.
# - Add a short “Must play / Do not play” list (e.g., preference for vocal jazz vs. instrumental, any songs to avoid).
# - Ensure licensing/royalty considerations are covered for public performance.
#
# Recommended initial direction (my pick)
# - Venue: The Peninsula Paris or Castille Paris are the strongest “first pass” options for a 100-guest jazz wedding in central Paris. The Peninsula offers a grand ballroom feel; Castille offers boutique charm with excellent service and potential for a more intimate ambiance. I’d start with these two to compare experience and quotes, and keep Four Seasons George V as a premium backup.
# - Flight strategy: Propose a small set of flight options that cover both budget-friendly and timing flexibility (e.g., one early morning option and one late afternoon option, with LTN/STN/LGW as primary sources). Then we can refine based on guest preferences and blocks.
# - Music plan: Use the current 20-track playlist as a base, then tailor to a formal cocktail hour, warm dinner, and dance-forward finale. Consider adding 2–3 live jazz options (quartet or duo) for a richer live feeling during dinner.
#
# Proposed next steps (please approve or adjust)
# 1) Flights specialist (delegate task)
# - Task: Pull a concise block of group-friendly London-to-Paris flight options for a wedding window in late May–early June.
# - Deliverables: 3–5 best options per key airports (LTN, STN, LGW, LHR) with times, durations, and estimated group rates or a plan to consolidate blocks for guests. Include recommended arrival windows for guests and any airline group booking benefits.
# - Timeline: 2–3 business days.
#
# 2) Venues specialist (delegate task)
# - Task: Contact Castille Paris, The Peninsula Paris, and Four Seasons George V for available dates in late May–early June, 2026; request package inclusions and tentative price ranges for a 100-person wedding (catering, venue rental, decor, and A/V).
# - Deliverables: A side-by-side comparison matrix (capacity confirmation, ceremony/reception layout options, inclusions, typical add-ons, and estimated total package range). Include notes on accessibility for live jazz, preferred floorplans, and potential ceremony sites within each venue.
# - Timeline: 5–7 business days (to allow for quotes and site visits if needed).
#
# 3) Music/Entertainment specialist (delegate task)
# - Task: Finalize a 60–90 minute cocktail/dinner/dance timeline with two to three live options (e.g., a jazz quartet, a DJ with live-sounding trumpet/sax overlays, or a small jazz trio) and a 20–30 track refined playlist tailored to each segment.
# - Deliverables: 2 timeline options (more relaxed vs. more dance-driven), a short “must-play” and “nice-to-have” list, and licensing/streaming notes. Also provide a plan for live music integration with the venue’s AV system and any needed permits.
# - Timeline: 3–5 business days.
#
# If you’d like, I can proceed to assign these tasks immediately and begin gathering quotes and options. I can also prepare a simple 1-page comparison sheet for your review as soon as the quotes come in.
#
# Quick questions to tailor the plan
# - Do you have preferred wedding dates or a date range in late May–early June 2026?
# - Is there a preferred airport cluster for guest arrivals (LHR, LGW, STN, LTN)?
# - Do you lean toward a more intimate boutique vibe (Castille) or a grand luxury vibe (Peninsula or Four Seasons)?
# - Any must-have elements for the jazz moment (e.g., live quartet for ceremony, specific songs for the first dance, champagne toast music)?
# - Budget rough ranges for venue and catering (per person or overall) to help the venue shortlist?
#
# If you confirm, I’ll kick off the specialist tasks right away and keep you updated with quotes, availability, and next steps.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
