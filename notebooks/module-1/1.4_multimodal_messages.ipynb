# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In a fictional setting, the capital of The Moon is Seleneapolis, commonly called Selene City.
#
# - Location: A sunlit plateau near the rim of Shackleton Crater on the Moon’s south polar region, built into domed rings that rise above the regolith.
# - Government: Seat of the Lunar Confederation; home to the Lunar Assembly and the central ministries that guide lunar policy, science, and trade with Earth.
# - Population: Roughly 10–15 million residents and workers within the city proper, with millions more in orbiting stations and nearby colonies.
# - Architecture and tech: Glass-domed neighborhoods, lattice-work lunar bricks, solar towers, ice-mining facilities, and a network of elevators and transit tunnels that stitch the city together.
# - Notable districts and features:
#   - Legislative Crescent: the government district housing the Lunar Assembly and council chambers.
#   - Lantern Quarter: cultural heart with museums, theaters, markets, and public plazas lit by solar-harvesting towers.
#   - Archive Basin: vast library and data vaults for lunar science, history, and interstellar archives.
#   - Great Beacon Tower: a towering solar beacon used for timekeeping, navigation, and ceremonial events.
# - Economy and culture: A hub for governance, science, tourism, and Earth-Lunar commerce; renowned for ice-water processing, research facilities, and a vibrant, multinational lunar culture.
#
# If you’d like, I can tailor Seleneapolis further—its history, rulers, famous districts, or key events in its rise to capital status.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon_city.png', 'type': 'image/png', 'size': 2812795, 'content': <memory at 0x10f736740>, 'last_modified': datetime.datetime(2025, 11, 13, 23, 11, 13, 130000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Nova Asterion, capital of the Jovian Pact, sits like a gleaming crown on the pale crust of a moon orbiting a colossal gas giant. The image you’ve shared captures its atmosphere: a city built for scarcity and grandeur, with gravity-defying architecture that hums under the light of a banded planet hanging in the sky.
#
# What makes Nova Asterion unique
# - Architecture: Asterion is a lattice of vertical spires and circular hubs linked by glassy skyways and mag-lev belts. Central to the skyline is the Convergence Spire, a tapered monument that houses the Pact’s high council and the city’s primary power core. Dome-covered markets and research domes nestle between the towers, creating a city of light and shadow rather than asphalt and brick.
# - Lighting and climate: The domes are clad in nano-matrix sunscreens that shift opacity with the planet’s daylight cycle, giving the city a perpetual dusky glow. Inside, climate domes and aquifer networks keep living spaces temperate, while the outer ring networks harvest solar energy and wind-like currents created by the giant planet’s atmosphere.
# - Atmosphere and culture: Asterion’s society prizes efficiency, precision, and shared purpose. Citizens—known as Asterians—value transparency, memory, and long-term planning. Public spaces double as memory archives, where holographic stories float just above pedestals, and art installations harvest ambient radiation to paint colors in the air.
# - Government: The city is the political heart of the Jovian Pact. Its leadership sits in the Council of Orbits, a rotating tri-council that represents science, industry, and civil rights. A sophisticated, city-wide feedback network ensures that the people’s voices influence policy through real-time simulations and citizen-scores (an ethical framework of consent and privacy).
# - Economy: Nova Asterion thrives on high-value, low-mass tech—nanofabricators, quantum memory shards, hydrogen loop power, and orbital logistics. The city doubles as a manufacturing hub and a diplomatic capital, where trade routes between moons and the gas giant’s rings converge.
# - Transportation: The Ringways—curved mag-lev corridors that encircle districts—allow rapid transit above the ground. Trolley-like routes weave between domes, and air-purifed corridors connect high-level offices with residential zones. Personal transit pods glide along invisible magnetic lines, allowing quick hops to a dome’s rooftop garden or a council chamber.
#
# Landmarks and districts
# - Convergence Spire: The tallest structure, housing the Pact’s council and the main fusion core. Its observation decks offer a view of the planet’s bands and the city’s ever-shifting glow.
# - The Orbital Market Rings: A string of domed bazaars where artisans trade memory-harboring data, luminescent fabrics, and starlit teas. The market’s centerpiece is the Glass Atrium, a transparent sphere that hosts seasonal exhibitions.
# - The Archive of Echoes: A public memory library where citizens deposit records and stories. It is also a defense of the city’s cultural identity—if you want a tradition, you must prove its value to the Archive.
# - The Desert Mirages: Square miles of gradually rising dunes sculpted into terraces and parks by climate engineers. It’s a public space of respite, where holographic constellations drift above moonlit sand.
# - The Ring of Echoing Towers: A ring of tall, thin spires whose resonant chambers amplify public addresses and broadcast music that can alter mood and focus.
#
# Daily life in Nova Asterion
# - People start their days with a communal moment at the Ringside Plaza, watching the planet’s bands sweep across the horizon while a chorus of drones performs a memory-haunting melody.
# - Work often happens within modular domes; scientists coordinate with engineers via shared holo-spaces, and artisans collaborate across districts through a network of memory ports.
# - Evenings feature light-based performances and open-air markets beneath the canopy of a sun-filtering dome. Food blends planetary minerals with synthetic flavors to create dishes that are both nostalgic and futuristic.
# - Education centers emphasize ethics of memory, planetary ecology, and systems thinking—youngsters learn by running simulations that affect real municipal decisions.
#
# A few plot seeds you could explore
# - A breach in the Convergence Spire’s core triggers an emergency that reveals a hidden faction within the Pact with a radical reinterpretation of memory rights.
# - A memory shard goes missing from the Archive of Echoes, sparking a city-wide hunt through the Desert Mirages and Ringways.
# - An envoy discovers a new, unstable energy source beneath the city that could power Nova Asterion for a century—or blow it all apart if mishandled.
# - A protest movement invokes an ancient “Memory Pact” that could force the council to re-balance science, governance, and art.
#
# Atmosphere you can feel from the image
# - The city breathes in a sea of dust and ionized air, while the giant striped planet looms as a constant reminder of the scale of civilization’s ambition.
# - The architecture’s sleek lines and glassy surfaces reflect a society obsessed with precision; life here unfolds with a cadence of measured steps and calculated risk.
#
# If you’d like, I can tailor Nova Asterion to a specific setting (military, democratic, corporate-dominated), adjust its technology level, or craft a short scene set in one of its districts. What mood or genre should this capital lean toward (political thriller, space opera, noir mystery, hopeful sci‑fi, etc.)?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.57it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# In the sunlit spots, they love to lay,
# With velvet paws, they prance and play.
# Mischief in their emerald eyes,
# Graceful leaps that touch the skies.
#
# Purring softly in the night,
# Their gentle gaze a soothing light.
# Independent, yet they roam,
# Bringing warmth to every home.
#
# Whiskers twitch and tails that sway,
# Mystic creatures of night and day.
# Silent steps and curious minds,
# In feline hearts, true friends we find.
