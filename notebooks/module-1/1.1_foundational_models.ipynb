# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or capital.\n\nIf you’re thinking of fiction, some stories invent capitals like “Lunapolis” or “Luna City,” but those are purely fictional. Want examples from a book or movie? I can look up some.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 646, 'prompt_tokens': 13, 'total_tokens': 659, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D6w7PtfNHb7rbWW5EJ9fpEAvAX6Q2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c3cc0-1396-79b2-9b83-302599d2cc98-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 646, 'total_tokens': 659, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital.
#
# If you’re thinking of fiction, some stories invent capitals like “Lunapolis” or “Luna City,” but those are purely fictional. Want examples from a book or movie? I can look up some.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-D6w7PtfNHb7rbWW5EJ9fpEAvAX6Q2',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 646,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 576,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 659}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or independent state, so it has no government and no capital.
#
# If you’re thinking of a science-fiction setting, I can suggest fictional capital names (e.g., Lunapolis, Seleneport, Moonhaven) or tailor something to a specific book or movie. Want me to come up with a few options?

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body without any permanent human settlements or governments.
#
# However, if we were to imagine a "capital" based on significant historical or scientific importance, some might playfully suggest:
#
# *   **The Sea of Tranquility (Mare Tranquillitatis):** This is where the Apollo 11 mission landed, and Neil Armstrong took his historic first steps. It's arguably the most famous and historically significant location on the Moon.
# *   **The South Pole-Aitken Basin:** This is the largest and oldest impact basin on the Moon. It's a region of immense scientific interest due to its potential to hold valuable resources and offer insights into the Moon's early history.
#
# But ultimately, the answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='34a7747a-35dd-4e93-ba80-0be626303608'),
#               AIMessage(content='There isn’t one—the Moon isn’t a country and has no government or capital. If you’re asking as a wordplay, the capital (uppercase) letter of “Moon” is M.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 624, 'prompt_tokens': 13, 'total_tokens': 637, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D6wF3WTE7nju10rRAslZwA0mXLeaQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c3cc7-4dbe-7b40-82cb-511a7dfc9409-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 624, 'total_tokens': 637, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one—the Moon isn’t a country and has no government or capital. If you’re asking as a wordplay, the capital (uppercase) letter of “Moon” is M.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='b3aea791-190b-44ec-982d-03e861aa7c75'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='1703f0eb-0312-4b90-8b52-1d25341497e2', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='045ad9d4-b73f-41f3-820d-2f09accc8e64'),
#               AIMessage(content='Just to be clear: there isn’t a real Luna City or any capital on the Moon. The Moon has no sovereign government or permanent city; humans have only temporary bases and research outposts so far. If you want, though, I can treat Luna City as a fictional lunar metropolis and build a plausible world around it. Here’s one possible concept:\n\nLuna City — a fictional lunar metropolis (late 21st century)\n- Location and purpose\n  - Situated on the rim of Shackleton Crater near the Moon’s south pole, chosen for access to water ice and periods of extended sunlight for solar power.\n  - Built as a hub for science, in situ resource utilization (ISRU), and a gateway for lunar industry and tourism.\n\n- Governance and society\n  - Governed by an International Lunar Authority (ILA) with a rotating council drawn from participating Earth nations and private partners.\n  - Civil life organized into districts: research, industry, housing, culture, and education. Laws focus on safety, resource sharing, and habitat protection.\n  - Population on the fictional timeline could range from a few thousand residents at first growth to tens of thousands as the city expands.\n\n- Economy and industry\n  - Water ice harvesting for life support (air and water recycling) and propellant production (LOX/LH2) for rockets.\n  - ISRU and manufacturing: regolith processing, 3D-printed components, and spare parts produced on-site to reduce Earth dependency.\n  - Tourism, scientific research, and education programs as growth engines.\n\n- Infrastructure and daily life\n  - Habitats: a network of domes and tunnels pressurized for 1-g equivalent comfort, with radiation shielding and thermal control.\n  - Energy: heavy use of solar arrays with energy storage; a small modular nuclear/thermal plant could be part of the mix to balance long lunar nights.\n  - Transportation: surface rovers and light rail-like transit along crater rims; pressurized transit between modules; drones for cargo.\n  - Life support: closed-loop air and water recycling, hydroponic/greenhouse food production, and airlocks for EVA safety.\n  - Timekeeping and rhythm: surface day on the Moon is about 29.5 Earth days, but residents live with artificial lighting and circadian-adjusted schedules inside habitats to maintain healthy sleep patterns.\n\n- Culture and life on the ground\n  - A blend of Earth cultures, with a unique lunar culture evolving around the rhythms of the Moon (long nights, long days, pristine darkness for stargazing, etc.).\n  - Education focuses on lunar science, engineering, and ethics of off-world living; arts and sports reflect the gravity and isolation of life off Earth.\n  - Special sites: a “Dome of Echoes” (cultural center), a market district for locally produced goods, and an “Archive Crater” housing mission logs and research data.\n\n- Challenges and risks\n  - Radiation exposure, regolith dust, micrometeoroid impacts, and the difficulty of supply chains.\n  - Psychological and social dynamics of living in a high-stress, small-community, extreme-environment setting.\n  - Environmental management: maintaining closed-loop systems, ensuring safe water, air, and food supplies.\n\nIf you’d like, I can tailor this for a specific vibe—more techno-thriller, more grounded science realism, a sci-fi romance, or a kid-friendly adventure. I can also write a short scene inside Luna City, draft a quick backstory for a key character, or create a layout map and a few district descriptions. Which direction would you prefer?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3236, 'prompt_tokens': 40, 'total_tokens': 3276, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 2496, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint':  ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional concept: a richly imagined capital of the Moon in a future or alternate-history setting. There is no real Luna City today, but if you’re building a story, game, or world, here’s a comprehensive, self-contained profile you can use or adapt.
#
# Quick snapshot
# - Role: Capital city and political/cultural heart of a lunar polity (a federation/coalition or sovereign lunar state in your setting).
# - Population: A few million residents (multinational mix of Earth-born migrants and Moon-born colonists).
# - Location: A crater-ringed foothold near the Moon’s south pole, leveraging water ice in permanently shadowed regions and abundant solar energy.
# - Vibe: A high-tech, modular civilization built for survival in a harsh environment, with a strong emphasis on governance, science, and interplanetary commerce.
#
# Overview and setting
# - Government: A centralized lunar authority (different names in your world—Lunaris Authority, United Lunar Confederation, etc.) with an elected or appointed executive, a legislature or council, and a judiciary. Luna City houses the main governing complex, the central archives, and the primary courts. The city often hosts interlunar summits and negotiations with Earth-based governments.
# - Economy: ISRU (in-situ resource utilization) drives most needs on-site: water ice, solar energy, oxygen, and metals. The city is a hub for research, space industry, cryotech, biotech, and lunar tourism. Trade routes connect Luna City to orbital hubs and Earth.
# - Culture: A cosmopolitan mix of Earth cultures adapted to lunar life. Language often blends English with local jargon and technical terms; a strong emphasis on community resilience, scientific curiosity, and public ceremonies. Public art, music, and theater celebrate the Moon’s stark beauty and its people’s ingenuity.
# - Technology level: Hard sci-fi vibes—robotics, 3D-printed regolith architecture, advanced life support, shielded habitats, magnetic/laser protection, autonomous transit systems, and mass-driver or mag-lev transfer between lunar sites.
#
# Location, geography, and districts
# - Core location: A permanently sunlit plateau near a permanently shadowed crater rim (to access water ice and sunlight in cycles). The city carefully distributes habitats to balance solar exposure and shade.
# - Administrative core (Pharos District): The main governance hub and spiritual/ceremonial center. Dominated by the Pharos Tower, a luminous, multi-purpose skyscraper that serves as a symbol of unity and a working government facility.
# - Ice Ward: Areas devoted to ISRU extraction facilities, water ice processing, and related research labs. Often near subsurface ice pockets and protected by regolith shielding.
# - Sol District: Solar-energy farms and power-infrastructure corridors, with surface-to-subsurface conduits and reflective array farms that keep the city supplied with clean power during long lunar days.
# - Arcology Ring: High-density residential and mixed-use arcologies that maximize living and working space while minimizing travel distances.
# - Harbor of Echoes (Spaceport Precinct): The main gateway for ships, cargo, tourism, and emergency response; stocked with repair yards, airlock hubs, and a visitor center with lunar history exhibits.
# - Icevault Quarter: Cultural and educational campus cluster with laboratories, universities, libraries, and museums showcasing lunar science, humanities, and public policy.
# - Observatory Terrace: A cluster around a major observatory for deep-space research, planetary defense simulations, and astronomical outreach to the public.
# - Market Crescent: Trade district with lunar countertops of goods, ISRU outputs, artisanal crafts, and international cuisine from Earth and Moon-born communities.
# - Quiet Districts: Low-noise, residential zones with extensive radiation shielding, parks, and wellness centers designed to offset lunar dust and gravity differences.
#
# Architecture, infrastructure, and daily life
# - Architecture: A mix of modular, 3D-printed regolith structures and translucent, radiation-shielding domes. Buildings emphasize energy efficiency, radiation protection, and modularity to withstand micrometeoroid impacts.
# - Housing: Arcologies combine living, working, and leisure in vertically layered ecosystems. Private domes are common in the wealthier districts; mid- and low-income neighborhoods use shared facilities with generous communal spaces.
# - Life support: Closed-loop systems for air, water, and waste, with hydroponic farms integrated into many blocks. Fresh food is partially produced on-site; most perishables are imported via orbital supply lines.
# - Mobility: Mag-lev or linear-train transit within Luna City, surface drones for deliveries, and a network of airlocks and tunnels linking districts. For longer hops, lunar orbits and transfer shuttles connect to orbital hubs.
# - Daily life: Residents work in research, governance, manufacturing, mining support, education, or service sectors. Evenings feature public viewing domes, lectures, lunar tours, and cultural festivals celebrating science and exploration. Education emphasizes STEM alongside lunar history and civics.
#
# History and politics (in-world lore)
# - Founding arc: After a period of interplanetary exploration and resource scarcity on Earth, a lunar compact established a semi-autonomous governance center on the Moon. Luna City grew as the capital, symbolizing lunar self-sufficiency and scientific leadership.
# - Key milestones: Expansion of ISRU infrastructure, the construction of the Pharos Tower, the establishment of the Icevault Quarter as a research and governance campus, and a recurring Interlunar Summit hosted in Luna City.
# - Political structure: A governing council or assembly with regional delegates from lunar settlements, plus an executive office (e.g., High Prefect, President, or Governor) and a judiciary. The city’s security forces coordinate with orbital defense units and neighboring settlements.
# - Conflicts and challenges: Competition for water and ice resources, solar-storm risk, gravity and radiation health programs to address long-term habitation, and tensions around autonomy versus Earth-led oversight. Cultural and scientific exchange with Earth remains vital.
#
# Economy, resources, and science
# - Primary resources: Water ice (from shadowed craters), metals and silicates from lunar regolith, solar energy, and high-value research outputs (biology, medicine, exoplanet studies, materials science).
# - Sectors: Government administration, ISRU and energy, spaceport services, advanced manufacturing and 3D printing, life sciences and biotech, education and culture, tourism and outreach.
# - Currency and trade: A lunar-credit system used within Luna City and lunar settlements, with conversions to Earth-based currency for interplanetary trade. Trade goods include research data, ice concentrate, manufactured parts, and tourism experiences.
# - Research and innovation: The Icevault Quarter hosts universities and labs focused on cryobiology, lunar geology, materials science, and environmental science. The Observatory Terrace pushes frontier astronomy and planetary defense simulations.
#
# Society, culture, and daily life
# - Demographics: A diverse population of Earth-born migrants, space industry workers, scientists, and Moon-born descendants. Language blends common Earth languages with technical lunar vocabulary and local slang.
# - Education: Universities with lunar, planetary, and engineering programs; public schools emphasize civics, STEM, and space history; strong adult education programs in life support, safety, and emergency response.
# - Arts and media: Lunar cinema, theater, and music celebrate exploration and resilience. Public art often uses light and shadow to reflect the Moon’s beauty; museums and archives preserve lunar science and colonial history.
# - Religion and philosophy: A spectrum of beliefs; some blends of Earth religions adapted to lunar life, plus secular humanist and scientific philosophies prized in public institutions.
# - Health and well-being: Medical centers focus on radiation exposure management, gravity adaptation, and cryo-preservation techniques. Fitness and mental health programs counteract isolation and sensory monotony.
#
# Landmarks and notable sites
# - The Pharos Tower: The iconic administrative beacon at the city core; a multifunction building housing government chambers, a public observatory, and ceremonial spaces.
# - The Lantern Cathedral: A grand place of worship and reflection that doubles as a civic forum during festivals.
# - The Icevault: A secure complex where water ice is processed, stored, and researched. Its glassy interiors glow with blue light from cryogenic systems.
# - The Moon Gate: A ceremonial entrance and transit hub linking Luna City to other lunar settlements and orbital stations.
# - The Heart of the City: A central plaza surrounded by markets, public art, and government buildings; a hub for festivals and announcements.
# - The Ice Harvest Square: A public square near ISRU facilities, where workers gather for briefings and seasonal celebrations.
# - The Arcology Spine: A vertical district with sweeping terraces, gardens, and mixed-use towers that demonstrates lunar urban design at scale.
# - The Observatory Terrace: A forward-looking research campus with telescope domes, planetary defense simulations, and educational outreach programs.
# - The Archives of Ansible: A vast digital and physical archive preserving lunar governance records, scientific data, and cultural artifacts.
# - The Lanterns of Lumen: An annual light-and-sound festival along the city’s edge, symbolizing resilience and the collaboration between Earth and Moon communities.
#
# Current issues, threats, and storytelling hooks
# - Resource stress: Water ice deposits are finite; new extraction techniques or political pressure to share resources can drive tensions between lunar districts and Earth authorities.
# - Environmental risk: Long lunar days and nights create thermal and radiation management challenges; solar storms can disrupt power and comms.
# - Health and social inequality: Access to energy, education, and healthcare varies by district, fueling social tension and inspiring stories about reform or rebellion.
# - Political drama: Debates over lunar autonomy vs. Earth oversight; elections, policy scandals, and intersettlement diplomacy provide fertile ground for intrigue.
# - Exploration and discovery: New subsurface ice pockets or mineral veins spark research breakthroughs and rival mining interests; discoveries can redefine power dynamics.
# - Crime and enforcement: The closed environment, massive infrastructure, and valuable resources invite smuggling, cyber-espionage, and governance challenges.
#
# Story seeds and prompts
# - A water crisis threatens Luna City’s life-support systems; a wandering lunar phenomenon reveals a new water source—but it’s in a contested area.
# - An Earth-backed corporation hacks a solar array to affect an upcoming vote; a team of investigators uncovers a deeper conspiracy linking orbital actors and lunar governance.
# - A young lunar-born scientist discovers a biosignature in a hydroponic system that suggests life can be sustained at lower-energy regimes, challenging established tech norms.
# - A festival on the Ice Harvest Square is used as cover for a covert mission to evacuate a high-ranking official under political threat.
# - A dispute over access to an ancient underground ice cavern pits multiple districts against each other and forces unlikely alliances.
#
# If you want, we can tailor Luna City to a specific tone
# - Hard sci-fi realism: Focus on engineering challenges, physics of the Moon, plausible ISRU systems, radiation shielding, and governance logistics.
# - Space opera: Emphasize political intrigue, grand diplomatic events, operatic culture, and sweeping space-age romance.
# - Dystopian/grim-dark: Investigate scarcity, factions, surveillance, and the human cost of living in a harsh lunar frontier.
# - Utopian/soft sci-fi: Highlight cooperative governance, sustainable design, lush public spaces, and vibrant artistic life.
#
# Would you like me to adapt this Luna City, for example:
# - to fit a particular era (near-term vs far-future),
# - to align with a specific political system or faction,
# - or to match a particular storytelling style or medium (novel, game, screenplay)?
