# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital. It’s currently uninhabited beyond temporary missions.\n\nIf you’re brainstorming fiction or a hypothetical future, people sometimes use names like Lunapolis or Selene for a lunar capital.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 769, 'prompt_tokens': 13, 'total_tokens': 782, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CkZQFEdCxUbH1KS7u4o0gI69n1q56', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--1b0636c3-893f-4107-acd2-3d9959dd2ca2-0', usage_metadata={'input_tokens': 13, 'output_tokens': 769, 'total_tokens': 782, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. It’s currently uninhabited beyond temporary missions.
#
# If you’re brainstorming fiction or a hypothetical future, people sometimes use names like Lunapolis or Selene for a lunar capital.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-CkZQFEdCxUbH1KS7u4o0gI69n1q56',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 769,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 704,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 782}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3-pro-preview")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)
# Out:
# /Users/sean/Documents/lca/demo/lc-foundations/.venv/lib/python3.12/site-packages/pydantic/v1/main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='0b1064ef-3ced-4e54-9592-2908f19c73f2'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital. Under the Outer Space Treaty, no nation owns the Moon, and there’s no sovereign government to designate a capital. If you’re thinking in fiction, you could imagine a capital named anything, but in reality there isn’t one.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 652, 'prompt_tokens': 13, 'total_tokens': 665, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cj91GzoNKfwA0IzBpGYy8JMam4YaS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--f1c25c9a-77da-4f38-aa6a-390dafb6fe7b-0', usage_metadata={'input_tokens': 13, 'output_tokens': 652, 'total_tokens': 665, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. Under the Outer Space Treaty, no nation owns the Moon, and there’s no sovereign government to designate a capital. If you’re thinking in fiction, you could imagine a capital named anything, but in reality there isn’t one.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='ca83b670-bd67-42cc-997f-08b236161b59'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='089719f2-9542-4824-9e17-b7b6659f5bf7'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='2fc50553-7d47-41b3-99b7-18a135a51b3c'),
#               AIMessage(content="You're right to question that—there isn’t a real capital of the Moon. Luna City isn’t an actual place; it’s a fictional concept. If you’d like, I can build a detailed fictional version of Luna City. Here are two options you might enjoy:\n\nOption A: Full world-building profile (hard sci-fi vibe)\n- Genre and tone: Near-future, plausible tech, space-set city.\n- Location: A lunar south-polar site near Shackleton crater, where sunlight-illuminated rims meet shadowed floors and there’s access to water ice.\n- Population and society: About 120,000 residents (engineers, scientists, families, support staff) with rotating visitors; governance by the Moon Council, an international, interagency body representing multiple spacefaring nations and commercial interests.\n- Infrastructure:\n  - Habitat clusters inside crater rim and underground networks beneath the shadowed floors.\n  - Regolith shielding for radiation protection; inflatable and rigid habitats; water mined from shadowed deposits and recycled.\n  - Power from large solar arrays on the rim plus small nuclear or battery backup for storms.\n  - Transportation includes elevator-tube links between levels, regional lunar rovers, and a lightweight maglev tram between districts.\n- Economy: Water-ice processing into life-support and propellant, lunar mining for metals, in-situ resource utilization (ISRU) factories, research and manufacturing in microgravity, and a growing space-tourism sector.\n- Architecture and daily life: Lightweight, modular housing with regolith-backed walls; communal farms in shielded modules; Earth-Moon communication hubs; schools teaching multilingual space science and lunar history.\n- Landmarks and districts: The Dome of Dawn (a bright, sun-facing research hub), Ice Lantern Market (ice-carved commerce), The Crater Archives (preserving lunar geology), and a public observatory with a view into space.\n- Challenges: Solar storms, cosmic radiation, micrometeoroid risk, dust management, life-support redundancy, mental health from long isolation, and supply-chain resilience.\n- Notable future events: The city becomes a permanent settlement in 2080, hosting international science missions and serving as a staging point for deeper lunar and cislunar operations.\n\nOption B: Short vignette (sample scene)\n- A quick scene set in Luna City—two engineers checking a water-ice refinery at the crater floor during a two-week night, with faint Earth glow on the horizon and the hum of life-support systems in the walls. If you want, I can write a 600–1000 word scene in this style.\n\nWould you like me to:\n- Write a complete, detailed profile like Option A, or\n- Create a vivid short vignette or scene set in Luna City, or\n- Shape Luna City to a specific tone (gritty realism, optimistic frontier, kid-friendly, corporate-thriller, etc.)?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2581, 'prompt_tokens': 40, 'total_tokens': 2621, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1984, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cj92aF82ZPuycHvkPCBPPJcorDEBX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--44dfd467-ff20-47a7-a145-f3f42fe58f64-0', usage_metadata={'input_tokens': 40, 'output_tokens': 2581, 'total_tokens': 2621, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1984}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is not a real place today, but a popular concept in science fiction and worldbuilding: a formal capital city built on the Moon, often imagined as the political, cultural, and economic heart of a lunar polity. If you’re creating a story, game, or just exploring ideas, here’s a rich, self-contained concept you can use or adapt.
#
# Core concept
# - Name: Luna City (capital of the Moon)
# - Nation/ polity: The Lunar Commonwealth (or United Lunar Republic) – a semi-sovereign, Earth-friendly lunar state with its own government, economy, and legal system.
# - Purpose: Political center, hub of science and industry, cultural flagship, and diplomatic liaison with Earth.
# - Population: A few hundred thousand to a couple million in large, shielded modules; a diverse mix of Earth-born settlers, long-term lunar residents, scientists, engineers, and migrants from other space settlements.
# - Tone: A hard sci-fi to near-future setting with room for political drama, exploration, and cultural evolution.
#
# Two plausible site concepts
# 1) Polar-lava-tube metropolis
# - Location: Near a crater rim at the Moon’s south pole (shielded from extreme heat and cold in places, with access to permanently shadowed craters for ice).
# - Why it works: abundant water ice for life support and fuel; near-constant solar opportunities for power in some shielded zones; natural shielding from micrometeoroids.
# - Design vibe: a network of interconnected shielded domes and excavated lava-tube sections, with glass skylights, transparent shielding, and retractable shielding for dust storms. Subsurface habitats minimize radiation exposure.
# - Challenges: temperature management in exposed areas, accessibility to Earth for heavy shipments, and deep reliance on water ice processing.
#
# 2) Equatorial lava-tube megacity
# - Location: A long lava tube near the equator, running beneath a shielded surface city with entrances to the outside for airlocks and exploration.
# - Why it works: easier to maintain a stable climate inside each dome, more straightforward solar access in a wide day-night cycle, straightforward surface transit routes.
# - Design vibe: a vertical-for-zen city with a central core, ring roads around the tube, and a “sunless” interior that uses advanced lighting to simulate day-night cycles. 3D-printed basalt and reinforced regolith form the bulk of the shell.
# - Challenges: balancing dust deposition from near-equatorial regions and maintaining long-term ice or propellant supplies.
#
# City layout (core ideas you can reuse)
# - Government and civic core
#   - Luna Assembly Hall: grand chamber for elections, debates, and formal addresses.
#   - Lunar Archives and Legal Quarter: housing the constitution, courtrooms, and historical records.
#   - Observatory District: a combined public telescope park and research facility, linking to Earth-based observatories.
# - Residential and community districts
#   - HabBlocks: modular living units arranged in hex-grid neighborhoods with shared gardens, nurseries, and play modules.
#   - Vertical Farms and Hydroponics Pavilions: food grown locally to reduce supply chain needs.
#   - Healthcare Arc: clinics and a lunar hospital with radiation shielding and telemedicine links to Earth.
# - Economic and industrial zones
#   - Sinter, Print, and Fabrication Corridors: 3D printers, basalt/ regolith processing, and microfabrication plants.
#   - Water Ice Processing Hub: distillation, electrolysis plants, and storage for life support and fuel.
#   - Energy Grid Quarter: solar arrays, nuclear microreactors, and energy storage facilities.
# - Cultural and public spaces
#   - Luna Museum of Heritage: lunar science, Earth–Moon history, and space art.
#   - Market District: a nightlife and food street with Earth-imported goods, lunar-grown produce, and artisanal crafts.
#   - The Green Dome: public gardens and bio-domes that provide fresh air and biodiversity.
# - Transport and security
#   - Transit Tunnels: pressurized corridors for pedestrians and freight.
#   - Lunar Elevator/Port: docking interfaces with orbital ships and cargo haulers.
#   - Security Sector HQ: lunar police, rescue, and crisis response units.
#
# Governance, law, and politics
# - Constitutional model: a representative council elected by districts, with a ceremonial head of state and a prime minister or president who chairs the council. A lunar high court settles disputes with Earth’s jurisdictions when needed.
# - Legal framework: strict dust-education, residency rules, and resource rights. A focus on water rights, mining licenses, and the management of energy, life support, and data sovereignty.
# - Political tensions (potential story hooks): Earth-lunar resource sharing, autonomy within the Earth-Moon framework, immigration and citizenship rules for new arrivals, and debates over environmental stewardship in closed habitats.
# - Security posture: civil defense against micrometeoroid showers and solar storms; cyber- and comms-security for critical infrastructure; a small, highly trained lunar guard for ceremonial duties and crisis response.
#
# Society and culture
# - Demographics: Earth-born citizens, new lunar-born generations, scientists, miners, and service workers. A mix of languages (Earth Standard as the main lingua franca, with Lunese as a growing local patois enriched by robotic terminologies and station slang).
# - Daily life: shifts around a stable indoor day-night cycle created by artificial lighting; regular maintenance and ice-harvesting routines; community kitchens and vertical gardens ensuring local food production.
# - Education and science: a strong emphasis on STEM, with specialized schools for astronautics, geology, water systems, and terraforming-adjacent research; a prominent university that attracts visiting scientists from Earth.
# - Culture: space-inspired arts, lunar poetry about dust and light, and festivals tied to lunar cycles and Earth seasons. Public exhibitions celebrate science, exploration, and collaborative Earth-lunar projects.
# - Cuisine: hydroponic greens, lab-grown proteins, ice-augmented beverages, and a culinary scene that fuses Earth traditions with lunar practicality (e.g., protein-rich algae, nutrient-rich ice desserts, and “dust-safe” cooking methods).
#
# Economy and technology
# - Key industries: water-ice extraction and processing, propellant production, high-precision manufacturing, and mining of regolith for construction materials. Growth industries include in-situ resource utilization (ISRU) R&D, space tourism (to Earth and around the Moon), and remote data services for Earth-based clients.
# - Currency and trade: a lunar currency (the Sol) used for internal trade, with Earth-based credits convertible through official exchanges. Trade with Earth includes precious metals, rare isotopes, and high-value data services.
# - Technology stack: closed-loop life support, artificial gravity solutions for certain zones, advanced radiation shielding, autonomous mining robots, 3D-printed buildings, and modular habitat tech. Energy is a mix of solar, nuclear microreactors, and energy storage systems.
#
# Landmarks and notable sites
# - The Great Gate: ceremonial entrance to Luna City, carved in smart stone and lit by fiber-optic veins.
# - Council Spire: the government complex with a transparent dome and a public viewing gallery.
# - The Ice Vault: reservoir and processor for water ice mined from polar craters.
# - The Observatory Plateau: a public-state-of-the-art observatory with a hub for lunar and Earth-based collaborations.
# - The Market Arc: a bustling commerce street with shops, eateries, and performers.
# - The Green Dome: a large biodome that supplies fresh food, air, and a calming public garden.
# - The Museum of Moon and Earth: a cultural bridge exploring the Moon’s past missions and future ambitions.
# - The Dust Theater: a venue for urban culture performances that celebrate lunar life.
#
# History and lore timeline (quick draft you can expand)
# - 2040s–2050s: First permanent outposts built for mining and science; Moon begins to stand on its own as a managed resource base.
# - 2060s: A patchwork of autonomous settlements forms a loose lunar federation.
# - 2080s: The Lunar Commonwealth signs a new treaty with Earth governments for resource sharing and political autonomy.
# - 2087: Luna City is founded as the capital, combining science, governance, and culture under a single, shielded umbrella.
# - 2090s–2100s: The city expands, develops a robust ISRU economy, and hosts Earth–Moon collaborative missions.
# - 2110s: A major crisis (dust storm/supply disruption) tests the city’s resilience, leading to stronger governance and a renewed focus on life-support redundancy.
#
# Story seeds and plot hooks
# - A political scandal threatens Luna City’s autonomy as Earth governments push new control measures over ISRU assets.
# - A groundbreaking water-ice discovery beneath the polar crater rewrites lunar energy and fuel economics.
# - A mysterious data breach reveals a hidden colony within a remote lava tube with its own governance—challenging Luna City’s authority.
# - An art-and-science festival triggers a race to deploy a new low-dust, climate-controlled bioregion in the Green Dome.
# - A mission to retrieve a long-lost Earth artifact uncovers a centuries-old lunar myth that redefines Moon-human identity.
#
# How to tailor to your project
# - For a hard sci-fi vibe: emphasize realistic physics, engineering constraints, life-support systems, radiation shielding, ISRU, and energy reliability. Keep tech grounded, with plausible timelines.
# - For a space opera tone: dial up grand institutions, intrigue, rival megacorporations, diplomatic crises, and sweeping visual design for architecture and fashion.
# - For a character-driven drama: focus on residents’ lives—the medical staff, engineers, teachers, and families who make life in Luna City possible amid the daily challenges of living on the Moon.
#
# If you tell me what you’re building (a novel, a game, a screenplay, a tabletop RPG, etc.) and the tone you want, I can tailor Luna City to your needs (scene-by-scene ideas, character bios, a one-page lore bible, or a detailed map and district descriptions).
