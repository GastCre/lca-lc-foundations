# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)
# Out:
# /Users/sean/Documents/lca/demo/lc-foundations/.venv/lib/python3.12/site-packages/pydantic/v1/main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='08c49ab7-1266-488b-848c-ce1e64e383d5'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—often tied to nature, growth, and balance. What would you like to do today? I can chat about colors, help with a project, answer questions, or just have a casual conversation. If you want, tell me a bit more about your interests and I can tailor things to you.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 530, 'prompt_tokens': 18, 'total_tokens': 548, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cj9j5qY6GTDgKtHRZMGrIXfoM71fo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--66424554-57b7-41d4-aed8-c0854d448362-0', usage_metadata={'input_tokens': 18, 'output_tokens': 530, 'total_tokens': 548, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='bc6bdced-2039-4fe4-a5b0-bad378675d92'),
#               AIMessage(content='I don’t know your favourite color yet. Want to figure it out together? Here are a few options:\n\n- Quick guessing game: I ask a few yes/no questions and try to guess your color.\n- Tell me a vibe: do you prefer bright or muted colors? warm (reds/oranges) or cool (blues/greens)?\n- Get a suggestion: I can pick a color I think you’ll like (blue is a common favorite), or tailor suggestions to a project (clothes, room, design).\n\nHow would you like to proceed?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 697, 'prompt_tokens': 11, 'total_tokens': 708, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cj9jIget2Ew8H1tDyiOG8RCznMUDh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--90a51b00-d787-4d8a-9689-b6217fe41375-0', usage_metadata={'input_tokens': 11, 'output_tokens': 697, 'total_tokens': 708, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='725bc34c-2ca4-4795-a1fe-0f66b8bbda37'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great choice—calming and full of life. Do you have a favorite shade, like forest green or emerald? How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 242, 'prompt_tokens': 18, 'total_tokens': 260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cj9mUQsZziXaaSNWA8PyQb1vhTjom', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--4e6dc452-9e6a-4fd2-a803-43923aea1b9e-0', usage_metadata={'input_tokens': 18, 'output_tokens': 242, 'total_tokens': 260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='725bc34c-2ca4-4795-a1fe-0f66b8bbda37'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great choice—calming and full of life. Do you have a favorite shade, like forest green or emerald? How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 242, 'prompt_tokens': 18, 'total_tokens': 260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cj9mUQsZziXaaSNWA8PyQb1vhTjom', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--4e6dc452-9e6a-4fd2-a803-43923aea1b9e-0', usage_metadata={'input_tokens': 18, 'output_tokens': 242, 'total_tokens': 260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='ac654923-4cb0-4554-b91b-2675ecb5464b'),
#               AIMessage(content='Your favourite colour is green, Seán.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 210, 'prompt_tokens': 74, 'total_tokens': 284, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Cj9meognKLWRck6PJaTveSVrnUwXg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--50ba3b55-05e7-4dd4-b480-db87c438eeac-0', usage_metadata={'input_tokens': 74, 'output_tokens': 210, 'total_tokens': 284, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}
