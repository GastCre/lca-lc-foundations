# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dataclass
class LanguageContext:
    user_language: str = "English"

@dynamic_prompt
def user_language_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on user role."""
    user_language = request.runtime.context.user_language
    base_prompt = "You are a helpful assistant."

    if user_language != "English":
        return f"{base_prompt} only respond in {user_language}."
    elif user_language == "English":
        return base_prompt

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Irish")
)

print(response["messages"][-1].content)
# Out:
# Dia dhuit! Conas is féidir liom cabhrú leat inniu? An bhfuil ceist agat, téacs míniú, aistriúchán, nó cabhair le scríbhneoireacht nó cód? Insíonn tú dom na sonraí agus déanfaimid é le chéile.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Spanish")
)

print(response["messages"][-1].content)
# Out:
# ¡Hola! ¿En qué puedo ayudarte hoy? Puedo:
#
# - Explicar conceptos o temas de estudio
# - Redactar, corregir o pulir textos
# - Resumir o traducir textos
# - Generar ideas, esquemas o listas
# - Ayudar con programación y debugging
# - Preparar ejercicios o preguntas de examen
# - Planificar proyectos o calendarios
#
# Dime qué tema o tarea necesitas, el nivel de detalle deseado y el tono (formal/informal). También indica si quieres otro idioma o formato específico.

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"message": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="French")
)

print(response["messages"][-1].content)
# Out:
# Bonjour ! Comment puis-je vous aider aujourd'hui ?
#
# Dites-moi ce dont vous avez besoin et je m’en occupe. Par exemple:
# - Traduction ou relecture
# - Explications ou apprentissage (maths, sciences, langues, histoire)
# - Rédaction ou révision (courriel, CV, lettre de motivation)
# - Aide informatique (programmation, débogage)
# - Résumés et synthèses
# - Planification, brainstorming ou organisation de projets
#
# N’hésitez pas à préciser le contexte et vos objectifs.
